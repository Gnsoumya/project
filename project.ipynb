# %%
import sys


class admin:
    def _init_(self,email,password,food_data):
        self.ad_email=email
        self.ad_passw=password
        self.food_data=food_data
        print("\nSelect one option from the following :")
        print("1.Add new items \n2.Edit items \n3.View items \n4.Remove item \n5.Exit\n")
        m=input()
        if m=="1":
            self.add_new_item()
        elif m=="2":
            self.edit_items()
        elif m=="3":
            self.view_items()
        elif m=="4":
            self.remove_item()
        elif m=="5":
            sys.exit()
        else:
            print("Please choose correct option")
            self._init_(self.ad_email,self.ad_passw,self.food_data)

    def add_new_item(self):
        x=[]
        name = input("Enter the name of new food : \n")
        x.append(name)
        quantity=input("Enter the quantity of food for ex.. : 1kg, 4 pieces\n")
        x.append(quantity)
        price=input("Enter the price of the food for ex... : INR 50, INR 100\n")
        x.append(price)
        discount=input("Enter the discount for the food for ex... : 5% OFF, 15% OFF\n")
        x.append(discount)
        stock=int(input("Enter the stock for ex... : 10, 5\n"))
        x.append(stock)
        self.food_data.append(x)
        print("Food item added successfully")
        self._init_(self.ad_email,self.ad_passw,self.food_data)
    
    
    def edit_items(self):
        print("\nSelect a food item to edit")
        for i in range(len(self.food_data)):
            print(str(i+1),end=". ")
            print(self.food_data[i])
        l=int(input())
        print("Selected food item is : ")
        print(self.food_data[l])
        print("Select the one to edit:")
        print("1.Edit name \n2.Edit quantity \n3.Edit price \n4.Edit discount \n5.Edit stock \n6.Go back")
        s=input()
        if s=="1":
            self.food_data[l][0]=input("Enter name to change: ")
            print("Name successfully changed")
        elif s=="2":
            self.food_data[l][1]=input("Enter quantity to change: ")
            print("Quantity successfully changed")
        elif s=="3":
            self.food_data[l][2]=input("Enter price to change: ")
            print("Price successfully changed")
        elif s=="4":
            self.food_data[l][3]=input("Enter discount to change: ")
            print("Discount successfully changed")
        elif s=="5":
            self.food_data[l][4]=input("Enter stock to change: ")
            print("Stock successfully changed")
        elif s==6:
            self._init_(self.ad_email,self.ad_passw,self.food_data)
        else:
            print("Please choose correct option")
            self.edit_items()            



        self._init_(self.ad_email,self.ad_passw,self.food_data)


    def remove_item(self):
        print("\nSelect a item to remove")
        print("For selecting 1st and 2nd items type 1 2")
        for i in range(len(self.food_data)):
            print(str(i+1)+". "+self.food_data[i])
        l=list(map(int,input().split()))
        print("\nSelected items are: \n")
        x=[]
        for i in range(len(l)):
            print(str(l[i])+". "+self.food_data[l[i]])
        print("Type Yes to Confirm and delete the above mentioned items")
        print("Type No to Cancel and go back")
        y=input()
        if y=="Yes":
            for i in l:
                del self.food_data[i]
            print("items selected are successfully deleted")
        elif y=="No":
            self._init_(self.ad_email,self.ad_passw,self.food_data)
        print()
        self._init_(self.ad_email,self.ad_passw,self.food_data)


    def view_items(self):
        print("Availabality of food: ")
        for i in range(len(self.food_data)):
            print(str(i+1)+". "+self.food_data[i][0]+" ("+self.food_data[i][1]+") "+" ["+self.food_data[i][2]+"] "+
            "Discount: "+self.food_data[i][3]+" Items in stock :"+str(self.food_data[i][4]))
        print()
        
        self._init_(self.ad_email,self.ad_passw,self.food_data)

        
    
class user:
    
    def _init_(self,email,password,full_name,phone,address,food_data,previos_orders):
        self.email = email
        self.password = password
        self.full_name = full_name
        self.phone = phone
        self.address = address
        self.user_data = []
        self.food_data = food_data
        self.previos_orders = previos_orders
    
    def create(self):
        self.user_data.append(self.email)
        self.user_data.append(self.password)
        self.user_data.append(self.full_name)
        self.user_data.append(self.phone)
        self.user_data.append(self.address)
        self.application()

    def application(self):
        print("\nChoose one :")
        print("1.Place new order \n2.Update Profile \n3.Order History \n4.Exit")
        k=input()
        if k=="1":
            self.place_order()
        elif k=="2":
            self.update_profile()
        elif k=="3":
            self.order_history()
        elif k=="4":
            sys.exit()
        else:
            print("Please choose correct option")
            self.application()

    def place_order(self):
        print("\nSelect items")
        print("Example: For selecting 1st and 2nd items type 1 2")
        for i in range(len(self.food_data)):
            print(str(i+1)+". "+self.food_data[i][0]+" ("+self.food_data[i][1]+") "+" ["+self.food_data[i][2]+"]")
        l=list(map(int,input().split()))
        print("\nSelected items are: \n")
        x=[]
        for i in range(len(l)):
            print(str(l[i])+". "+self.food_data[l[i]-1][0]+" ("+self.food_data[l[i]-1][1]+") "+" ["+self.food_data[l[i]-1][2]+"]")
            x.append(str(l[i])+". "+self.food_data[l[i]-1][0]+" ("+self.food_data[l[i]-1][1]+") "+" ["+self.food_data[l[i]-1][2]+"]")
        print()
        k=0
        for i in range(len(l)):
            if self.food_data[l[i]-1][4]==0:
                    k=1
                    print(self.food_data[l[i]-1][0]+" is out of stock\n")

                    
        if k==1:
            print("Type Change to select other items or Cancel to go back\n")
            p=input()
            if p=="Change":
                self.place_order()
            elif p=="Cancel":
                self.application()
        print("\nType Yes to confirm your order and No to go back")
        print("Type Change to change your order\n")
        k=input()
        if k=="Yes":
            print("\nOrder confirmed\n")
            self.prev_orders.append(x)
            for i in range(len(l)):
                self.food_data[l[i]-1][4]-=1
            self.application()
        elif k=="No":
            self.application()
        elif k=="Change":
            self.place_order()

    def order_history(self):
        print("These are the previous orders:\n")
        if len(self.prev_orders)==0:
            print("No orders placed, to view order history please order an item.\n")
            self.application()
        else:
            for i in self.prev_orders:
                print(i)
            self.application()

    def update_profile(self):
        print("\nChoose the below options to change data")
        print("1.Email \n2.Password \n3.Full Name \n4.Phone \n5.Address \n6.Change another data \n7.Exit\n" )
        h=input()
        if h=="1":
            print("Enter new Email to update: ")
            self.user_data[0]=input()
            print("Email updated successfully")
            self.update_profile()
        elif h=="2":
            print("Enter new Password to update: ")
            self.user_data[1]=input()
            print("Password updated successfully")
            self.update_profile()
        elif h=="3":
            print("Enter new Full Name to update: ")
            self.user_data[2]=input()
            print("Full Name updated successfully")
            self.update_profile()
        elif h=="4":
            print("Enter new Phone to update: ")
            self.user_data[3]=input()
            print("Phone update successfully")
            self.update_profile()
        elif h=="5":
            print("Enter new Address to update: ")
            self.user_data[4]=input()
            print("Address update successfully")
            self.update_profile()
        elif h=="6":
            self.update_profile()
        elif h=="7":
            self.application()
        else:
            print("Please choose correct option")
            self.update_profile()

        
def take_input(food_data,previos_orders):
    
        user_input=input()
        if user_input=="1": #admin login
            ad_email=input("Enter admin email: ")
            ad_passw= input("Enter admin password: ")
            print()
            if ad_email=="soumya123@gmail.com" and ad_passw=="password":
                admin_login=admin(ad_email,ad_passw,food_data)
                admin_login()
            else:
                print("Please enter correct email and password")
                choose()
    
        elif user_input=="2": #new user
            full_name=input("Enter your full name: ")
            phone=input("Enter your phone number: ")
            email=input("Enter your email address: ")
            address=input("Enter your address: ")
            password=input("Enter your password: ")
            create_user=user(email,password,full_name,phone,address,food_data,previos_orders)
            create_user.create()
        elif user_input=="3":
            sys.exit()

        else:
            print("Please choose correct option")
            choose()
 
    

def choose():
    print("\nChoose any one option from the following :")
    print("1.Admin login \n2.User Login \n3.Exit\n")
    take_input([["roti","2 pieces","INR 240","10% OFF",2],
    ["pizza","2 piece","INR 500","10% OFF",2],
    [" pastry","1 kg","INR 2000","20% OFF",2]],[])


print("Welcome")
choose()
# Out:
# Welcome to  our Food Ordering App
#
# Choose any one option from the following :
# 1.Admin login
# 2.User Login
# 3.Exit
#
# 1
# Enter admin email: soumya123@gmail.com
# Enter admin password: password
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13480/3042743502.py in <module>
#     276
#     277 print("Welcome to  our Food Ordering App")
# --> 278 choose()
#
# ~\AppData\Local\Temp/ipykernel_13480/3042743502.py in choose()
#     270     print("\nChoose any one option from the following :")
#     271     print("1.Admin login \n2.User Login \n3.Exit\n")
# --> 272     take_input([["roti","2 pieces","INR 240","10% OFF",2],
#     273     ["pizza","1 piece","INR 320","10% OFF",2],
#     274     [" Cake","500 gm","INR 900","10% OFF",2]],[])
#
# ~\AppData\Local\Temp/ipykernel_13480/3042743502.py in take_input(food_data, prev_orders)
#     244             print()
#     245             if ad_email=="soumya123@gmail.com" and ad_passw=="password":
# --> 246                 admin_login=admin(ad_email,ad_passw,food_data)
#     247                 admin_login()
#     248             else:
#
# TypeError: admin() takes no arguments
